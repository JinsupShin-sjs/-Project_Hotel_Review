# %% [markdown]
# ### 1. 파일 불러오기

# %%
import pandas as pd

train_data = pd.read_csv('c:/프로젝트/Hotel Review/Data/review_jeju50_train_0601.csv',encoding='ms949')
test_data = pd.read_csv('c:/프로젝트/Hotel Review/Data/review_jeju50_test_0601.csv',encoding='ms949')
tag_data = pd.read_csv('c:/프로젝트/Hotel Review/Data/review_jeju50_0601_F_1.csv',encoding='ms949')

# %%
len(train_data)
# Out:
# 20000

# %%
train_data[:3]
# Out:
#                   name       title  score  label  \
# 0    랜딩관 제주신화월드 호텔앤리조트        3603    8.0      0
# 1  메리어트관 제주신화월드 호텔앤리조트        3603    8.0      0
# 2    랜딩관 제주신화월드 호텔앤리조트  1051745507    8.0      0
#
#                                               review
# 0  시설도 깨끗하고 객실 뷰도 좋았어요!!! 수영장도 시설이 너무 좋았어요. 주차시설이...
# 1  시설도 깨끗하고 객실 뷰도 좋았어요!!! 수영장도 시설이 너무 좋았어요. 주차시설이...
# 2  돌담집을 제외한 다른 모든 면에서 만족스러운 호텔이었음(돌담집에서 고객을 응대하는 ...

# %%
len(test_data)
# Out:
# 10000

# %%
test_data[:3]
# Out:
#        name  title  score  label  \
# 0  호텔 샬롬 제주  매우 좋음    8.0      0
# 1    아스타 호텔  매우 좋음    8.0      0
# 2  신라스테이 제주  매우 좋음    8.0      0
#
#                                               review
# 0  제주 시내에 위치하여 걸어서 주변 시내를 돌아다닐 수 있습니다 식당도 많고 산책겸 ...
# 1                                  제주 시내에 위치한 가성비 호텔
# 2  제주 시내에 있어 접근성이 좋습니다. 렌트카로 갔지만 대중교통이나 택시를 이용해서도...

# %%
train_data['score'].hist()
# Out:
# <Axes: >

# %%
test_data['score'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### 2. 전처리

# %%
train_data['review'].nunique(),train_data['label'].nunique()
# Out:
# (17781, 2)

# %%
#중복값 제거
train_data.drop_duplicates(subset=['review'],inplace=True)
len(train_data)
# Out:
# 17781

# %%
import matplotlib.pyplot as plt
train_data['label'].value_counts().plot(kind = 'bar')
plt.show()

# %%
train_data.loc[train_data.review.isnull()]
# Out:
# Empty DataFrame
# Columns: [name, title, score, label, review]
# Index: []

# %%
#특수문자,기호 제거
train_data['review'] =train_data['review'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 A-Za-z]","")
train_data['review'] =train_data['review'].str.replace('[.,!?"\':;~()]','')
train_data[:3]
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_14056\2866373672.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['review'] =train_data['review'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 A-Za-z]","")
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_14056\2866373672.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['review'] =train_data['review'].str.replace('[.,!?"\':;~()]','')
#                 name       title  score  label  \
# 0  랜딩관 제주신화월드 호텔앤리조트        3603    8.0      0
# 2  랜딩관 제주신화월드 호텔앤리조트  1051745507    8.0      0
# 5      히든 클리프 호텔&네이쳐           -    3.0      0
#
#                                               review
# 0  시설도 깨끗하고 객실 뷰도 좋았어요 수영장도 시설이 너무 좋았어요 주차시설이 너무 ...
# 2  돌담집을 제외한 다른 모든 면에서 만족스러운 호텔이었음돌담집에서 고객을 응대하는 방...
# 5                                아침식사와 직원분들은 친절하셨습니다

# %%
import numpy as np
#공백 제거
train_data['review'] =train_data['review'].str.replace('^ +', "")
train_data['review'].replace('', np.nan, inplace=True)
train_data.isnull().sum()
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_14056\298783350.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['review'] =train_data['review'].str.replace('^ +', "")
# name       0
# title      0
# score      0
# label      0
# review    56
# dtype: int64

# %%
train_data.loc[train_data.review.isnull()][:3]
# Out:
#              name                 title  score  label review
# 1435     롯데 호텔 제주            家族でも、友達とでも    6.0      0    NaN
# 1546     롯데 호텔 제주            家族連れにはぴったり    8.0      0    NaN
# 1895  더 베스트 제주 성산  价格?惠，但房??小，??人住有点??。    5.0      0    NaN

# %%
train_data = train_data.dropna(how = 'any')
len(train_data)
# Out:
# 17725

# %%
# test_data에도 동일한 과정 적용
test_data.drop_duplicates(subset = ['review'],inplace=True)

# %%
test_data['review'] = test_data['review'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
test_data['review'] =test_data['review'].str.replace('[.,!?"\':;~()]','')
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_14056\833855062.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   test_data['review'] = test_data['review'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_14056\833855062.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   test_data['review'] =test_data['review'].str.replace('[.,!?"\':;~()]','')

# %%
test_data['review'] =train_data['review'].str.replace('^ +', "")
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_14056\2836428721.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   test_data['review'] =train_data['review'].str.replace('^ +', "")

# %%
test_data['review'].replace('', np.nan, inplace=True)
test_data = test_data.dropna(how='any')
len(test_data)
# Out:
# 7933

# %% [markdown]
# ### 3. 한글 형태소 분석 및 토큰화

# %%
stopwords =['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다','제주', '제주도', '호텔', '리뷰', '숙소', '여행', '트립']

# %%
# 형태소
from konlpy.tag import Okt
from collections import Counter
okt = Okt()
X_train = []
for sentence in train_data['review']: 
    temp_X = okt.morphs(sentence, stem=True)
    temp_X = [word for word in temp_X if not word in stopwords] 
    X_train.append(temp_X)

# %%
print(X_train[:3])
# Out:
# [['시설', '깨끗하다', '객실', '뷰', '좋다', '수영장', '시설', '너무', '좋다', '주차', '시설', '너무', '좋다', '또', '오다', '싶다', '애', '방학', '을', '맞이', '오다', '담', '또', '오다', '싶다'], ['돌담', '집', '을', '제외', '다른', '모든', '면', '에서', '만족스럽다', '이다', '돌담', '집', '에서', '고객', '을', '응대', '방법', '일반', '여관', '이하', '수준', '이다'], ['아침식사', '직원', '분들', '친절하다']]

# %%
# 테스트 데이터에 대한 토큰화
X_test = []
for sentence in test_data['review']:
    temp_X = okt.morphs(sentence, stem=True)
    temp_X = [word for word in temp_X if not word in
    stopwords]
    X_test.append(temp_X)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
print(tokenizer.word_index)
# Out:
# {'좋다': 1, '있다': 2, '너무': 3, '을': 4, '이다': 5, '없다': 6, '위치': 7, '직원': 8, '에서': 9, '시설': 10, '친절하다': 11, '조식': 12, '않다': 13, '객실': 14, '이용': 15, '로': 16, '깨끗하다': 17, '같다': 18, '되다': 19, '아쉽다': 20, '자다': 21, '오다': 22, '보다': 23, '가격': 24, '수영장': 25, '다': 26, '것': 27, '뷰': 28, '비': 29, '수': 30, '가족': 31, '넓다': 32, '가다': 33, '되어다': 34, '가성': 35, '많다': 36, '가깝다': 37, '곳': 38, '인': 39, '적': 40, '침대': 41, '편하다': 42, '분들': 43, '룸': 44, '안': 45, '조금': 46, '깔끔하다': 47, '방': 48, '때': 49, '주차': 50, '매우': 51, '하고': 52, '아이': 53, '해주다': 54, '고': 55, '정말': 56, '분': 57, '점': 58, '불편하다': 59, '주변': 60, '이라': 61, '더': 62, '공항': 63, '생각': 64, '방문': 65, '다음': 66, '만': 67, '주차장': 68, '먹다': 69, '서비스': 70, '까지': 71, '최고': 72, '맛있다': 73, '요': 74, '층': 75, '들다': 76, '등': 77, '화장실': 78, '만족하다': 79, '또': 80, '싶다': 81, '아주': 82, '바다': 83, '괜찮다': 84, '모두': 85, '아니다': 86, '바로': 87, '못': 88, '정도': 89, '청소': 90, '편안하다': 91, '나': 92, '많이': 93, '신화': 94, '대비': 95, '시간': 96, '그리고': 97, '안되다': 98, '크다': 99, '체크': 100, '에도': 101, '침구': 102, '내': 103, '보이다': 104, '만족스럽다': 105, '예약': 106, '컨디션': 107, '근처': 108, '앞': 109, '다른': 110, '숙박': 111, '아침': 112, '시': 113, '청결': 114, '거리': 115, '월드': 116, '에는': 117, '조용하다': 118, '리조트': 119, '편의점': 120, '식당': 121, '제': 122, '냄새': 123, '다시': 124, '라': 125, '욕실': 126, '그렇다': 127, '추천': 128, '그': 129, '특히': 130, '청결하다': 131, '사용': 132, '상태': 133, '편리하다': 134, '소리': 135, '시장': 136, '느낌': 137, '개': 138, '받다': 139, '이나': 140, '모든': 141, '좁다': 142, '문': 143, '방이': 144, '인데': 145, '음식': 146, '방음': 147, '주다': 148, '작다': 149, '서': 150, '묵다': 151, '넘다': 152, '박': 153, '면': 154, '날': 155, '게': 156, '샤워': 157, '전망': 158, '저렴하다': 159, '중': 160, '별로': 161, '옆': 162, '부분': 163, '친절': 164, '쉬다': 165, '함께': 166, '이랑': 167, '식사': 168, '하나': 169, '다양하다': 170, '두': 171, '및': 172, '일': 173, '만족': 174, '전반': 175, '기': 176, '쾌적하다': 177, '즐기다': 178, '나다': 179, '랑': 180, '바닥': 181, '수건': 182, '안내': 183, '시내': 184, '물': 185, '감사하다': 186, '공간': 187, '편의': 188, '대': 189, '기분': 190, '투숙': 191, '성': 192, '지내다': 193, '주': 194, '부터': 195, '엔': 196, '함': 197, '나오다': 198, '훌륭하다': 199, '저녁': 200, '사람': 201, '없이': 202, '때문': 203, '처음': 204, '비다': 205, '밤': 206, '올': 207, '갈다': 208, '이동': 209, '로비': 210, '관리': 211, '온': 212, '가능하다': 213, '건물': 214, '서머셋': 215, '소음': 216, '부대': 217, '전체': 218, '꼭': 219, '놀다': 220, '맛': 221, '맛집': 222, '마음': 223, '저': 224, '산책': 225, 'ㅠㅠ': 226, 'ㅎㅎ': 227, '오션': 228, '좋아하다': 229, '여서': 230, '내부': 231, '이번': 232, '동': 233, '듯': 234, '다만': 235, '메뉴': 236, '쪽': 237, '뷔페': 238, '필요하다': 239, '먼지': 240, '번': 241, '요청': 242, '늦다': 243, '그냥': 244, '걸다': 245, '방도': 246, '욕조': 247, '부족하다': 248, '선택': 249, '찾다': 250, '약간': 251, '엄청': 252, '무료': 253, '모르다': 254, '급': 255, '재': 256, '한라산': 257, '잠': 258, '아침식사': 259, '오래되다': 260, '보내다': 261, '나가다': 262, '응대': 263, '거': 264, '해': 265, '느끼다': 266, '장': 267, '즐겁다': 268, '하': 269, '크기': 270, '머물다': 271, '지': 272, '실내': 273, '다니다': 274, '객': 275, '마다': 276, '물이': 277, '아기': 278, '들어가다': 279, '차다': 280, '프론트': 281, '창문': 282, '들리다': 283, '분위기': 284, '파크': 285, '드리다': 286, '차': 287, '진짜': 288, '성산일출봉': 289, '명': 290, '이상': 291, '멀다': 292, '코로나': 293, '하루': 294, '테마': 295, '부모님': 296, '후': 297, '이고': 298, '여러': 299, '따뜻하다': 300, '알다': 301, '종류': 302, '떨어지다': 303, '네': 304, '비싸다': 305, '무엇': 306, '에어컨': 307, '말': 308, '롯데': 309, '힘들다': 310, '여기': 311, '들어오다': 312, '높다': 313, '서귀포': 314, '조': 315, '접근성': 316, '제공': 317, '식': 318, '야외': 319, '저희': 320, '빼다': 321, '또한': 322, '딱': 323, '여': 324, '전': 325, '워터파크': 326, '아쉬움': 327, '인지': 328, '랜딩관': 329, '돼다': 330, '문제': 331, '시끄럽다': 332, '니': 333, '한번': 334, '풀': 335, '쉬': 336, '하지만': 337, '그래도': 338, '인하다': 339, '장이': 340, '집': 341, '가장': 342, '준비': 343, '신경': 344, '중문': 345, '외': 346, '테라스': 347, '복도': 348, '움': 349, '전혀': 350, '업그레이드': 351, '완전': 352, '어메니티': 353, '테이블': 354, '기대': 355, '랜딩': 356, '맘': 357, '냉장고': 358, '끄다': 359, '가기': 360, '굿': 361, '주차공간': 362, '도착': 363, '추가': 364, '의사': 365, '동안': 366, '해결': 367, '에게': 368, '낡다': 369, '류': 370, '편이': 371,  ...

# %%
# 출현빈도가 3회 미만인 단어들
threshold = 3
total_cnt = len(tokenizer.word_index) 
rare_cnt = 0
total_freq = 0
rare_freq = 0
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value
print(total_cnt)
print(rare_cnt)
# Out:
# 11785
# 6473

# %%
vocab_size = total_cnt -rare_cnt + 1
print(vocab_size)
# Out:
# 5313

# %%
tokenizer = Tokenizer(vocab_size)
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
import joblib
joblib.dump(tokenizer, 'RNN_11tokenizer.h5')
# Out:
# ['RNN_11tokenizer.h5']

# %%
print(X_train[:3])
# Out:
# [[10, 17, 14, 28, 1, 25, 10, 3, 1, 50, 10, 3, 1, 80, 22, 81, 434, 3556, 4, 1030, 22, 749, 80, 22, 81], [3557, 341, 4, 1192, 110, 141, 154, 9, 105, 5, 3557, 341, 9, 554, 4, 263, 2017, 844, 3558, 1567, 457, 5], [259, 8, 43, 11]]

# %%
y_train = np.array(train_data['label'][:])
y_test = np.array(test_data['label'][:])

# %%
max_len = max(len(l) for l in X_train)

# %%
cnt = 0
for s in X_train:
    if(len(s) <= 30):
        cnt = cnt + 1
(cnt / len(X_train))*100
# Out:
# 82.73060648801128

# %% [markdown]
# ### 4. 모델 학습 / 성능 평가 / 예측정확도

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
X_train = pad_sequences(X_train, maxlen = max_len)
X_test = pad_sequences(X_test, maxlen = max_len)

# %%
from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

model = Sequential()
model.add(Embedding(vocab_size, 200))
model.add(LSTM(128))
model.add(Dense(1, activation='sigmoid'))  
model.compile(optimizer='rmsprop',
loss='binary_crossentropy', metrics=['acc'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 200)         1062600
#
#  lstm (LSTM)                 (None, 128)               168448
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 1,231,177
# Trainable params: 1,231,177
# Non-trainable params: 0
# _________________________________________________________________

# %%
es = EarlyStopping(monitor='val_loss', mode='min',patience=5)
mc = ModelCheckpoint('RNN_11model.h5', monitor='val_acc',mode='max', verbose=1, save_best_only=True)
model.fit(X_train, y_train, batch_size = 64, epochs=10,validation_split=0.2, callbacks=[es, mc])
# Out:
# Epoch 1/10
# 221/222 [============================>.] - ETA: 0s - loss: 0.6308 - acc: 0.6524
# Epoch 1: val_acc improved from -inf to 0.35289, saving model to RNN_11model.h5
# 222/222 [==============================] - 17s 62ms/step - loss: 0.6307 - acc: 0.6525 - val_loss: 1.0091 - val_acc: 0.3529
# Epoch 2/10
# 221/222 [============================>.] - ETA: 0s - loss: 0.5677 - acc: 0.7009
# Epoch 2: val_acc improved from 0.35289 to 0.40339, saving model to RNN_11model.h5
# 222/222 [==============================] - 13s 60ms/step - loss: 0.5678 - acc: 0.7008 - val_loss: 0.9324 - val_acc: 0.4034
# Epoch 3/10
# 221/222 [============================>.] - ETA: 0s - loss: 0.5267 - acc: 0.7330
# Epoch 3: val_acc did not improve from 0.40339
# 222/222 [==============================] - 13s 60ms/step - loss: 0.5267 - acc: 0.7331 - val_loss: 1.2406 - val_acc: 0.3109
# Epoch 4/10
# 221/222 [============================>.] - ETA: 0s - loss: 0.4918 - acc: 0.7584
# Epoch 4: val_acc improved from 0.40339 to 0.55515, saving model to RNN_11model.h5
# 222/222 [==============================] - 16s 73ms/step - loss: 0.4919 - acc: 0.7585 - val_loss: 0.8557 - val_acc: 0.5551
# Epoch 5/10
# 221/222 [============================>.] - ETA: 0s - loss: 0.4583 - acc: 0.7747
# Epoch 5: val_acc did not improve from 0.55515
# 222/222 [==============================] - 16s 71ms/step - loss: 0.4583 - acc: 0.7747 - val_loss: 1.2927 - val_acc: 0.3977
# Epoch 6/10
# 221/222 [============================>.] - ETA: 0s - loss: 0.4276 - acc: 0.7974
# Epoch 6: val_acc did not improve from 0.55515
# 222/222 [==============================] - 14s 62ms/step - loss: 0.4277 - acc: 0.7973 - val_loss: 1.0920 - val_acc: 0.4773
# Epoch 7/10
# 221/222 [============================>.] - ETA: 0s - loss: 0.3945 - acc: 0.8170
# Epoch 7: val_acc did not improve from 0.55515
# 222/222 [==============================] - 14s 62ms/step - loss: 0.3945 - acc: 0.8171 - val_loss: 1.2933 - val_acc: 0.4685
# Epoch 8/10
# 221/222 [============================>.] - ETA: 0s - loss: 0.3690 - acc: 0.8288
# Epoch 8: val_acc did not improve from 0.55515
# 222/222 [==============================] - 18s 79ms/step - loss: 0.3687 - acc: 0.8290 - val_loss: 1.4713 - val_acc: 0.4358
# Epoch 9/10
# 221/222 [============================>.] - ETA: 0s - loss: 0.3424 - acc: 0.8413
# Epoch 9: val_acc did not improve from 0.55515
# 222/222 [==============================] - 14s 63ms/step - loss: 0.3423 - acc: 0.8415 - val_loss: 1.6296 - val_acc: 0.4742

# %%
loaded_model = load_model('RNN_11model.h5')
loaded_model.evaluate(X_test, y_test)
# Out:
# 248/248 [==============================] - 4s 14ms/step - loss: 0.9290 - acc: 0.4997
# [0.9290133118629456, 0.4996848702430725]

# %% [markdown]
# ### 5. Revies 예측

# %%
import math
def review_predict(new_sentence):
    new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
    new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
    encoded = tokenizer.texts_to_sequences([new_sentence]) #정수 인코딩
    pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
    score = float(model.predict(pad_new)) # 예측
    if( score < 0.1): 
        print(f"예상 평점 {math.trunc(score* 10)}점 -> 매우 부정 리뷰입니다.\n")
    elif( score >= 0.1 and score < 0.2): 
        print(f"예상 평점 {math.trunc(score* 10)}점 -> 매우 부정 리뷰입니다.\n")
    elif(score >= 0.2 and score < 0.3):
        print(f"예상 평점 {math.trunc(score* 10)}점 -> 부정 리뷰입니다.\n")
    elif(score >= 0.3 and score < 0.4):
        print(f"예상 평점 {math.trunc(score* 10)}점 -> 부정 리뷰입니다.\n")
    elif(score >= 0.4 and score < 0.5):
        print(f"예상 평점 {math.trunc(score* 10)}점 -> 부정 리뷰입니다.\n")
    elif(score >= 0.5 and score < 0.6):
        print(f"예상 평점 {math.trunc(score* 10)}점 -> 보통 리뷰입니다.\n")
    elif(score >= 0.6 and score < 0.7):
        print(f"예상 평점 {math.trunc(score* 10)}점 -> 보통 리뷰입니다.\n")
    elif(score >= 0.7 and score < 0.8):
        print(f"예상 평점 {math.trunc(score* 10)}점 -> 긍정 리뷰입니다.\n")
    elif(score >= 0.8 and score <= 0.9):
        print(f"예상 평점 {math.trunc(score* 10)}점 -> 긍정 리뷰입니다.\n")
    elif(score > 0.9 and score <= 1.0):
        print(f"예상 평점 {math.trunc(score* 10)}점 -> 매우 긍정 리뷰입니다.\n")
    # else:
    #     print(f"예상 평점 {math.trunc(score* 10)}점 -> 긍정 리뷰입니다.~\n")
    #print(score)

# %%
review_predict('공간이 넓어서 셋이 지내기도 불편하지 않았다')
# Out:
# 1/1 [==============================] - 0s 351ms/step
# 예상 평점 5점 -> 보통 리뷰입니다.

# %%
review_predict('2박동안 조식메뉴가 똑같았다는게 조금 아쉽습니다')
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 예상 평점 2점 -> 부정 리뷰입니다.

# %%
review_predict('1층이 좀 답답하게 느껴졌음')
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 예상 평점 1점 -> 매우 부정 리뷰입니다.

# %%
review_predict('공간이 좁아서 혼자 지내기도 불편했다')
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 예상 평점 3점 -> 부정 리뷰입니다.

# %%
review_predict('공간은 좁지만 혼자 지내기 충분했다')
# Out:
# 1/1 [==============================] - 0s 26ms/step
# 예상 평점 4점 -> 부정 리뷰입니다.

# %%
review_predict('수영장이 좋고 단지내에 할 수 있는 것이 많았다')
# Out:
# 1/1 [==============================] - 0s 112ms/step
# 예상 평점 6점 -> 보통 리뷰입니다.

# %%
review_predict('신회월드는 숙소도 좋지만 식당가가 훌륭합니다.한식당 선은 매우 훌륭한데. 육전 강추입니다.')
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 예상 평점 6점 -> 보통 리뷰입니다.

# %%
review_predict('잘 선택했다는 좋은 하루였습니다')
# Out:
# 1/1 [==============================] - 0s 21ms/step
# 예상 평점 2점 -> 부정 리뷰입니다.

# %%
review_predict('해외나가지 않아도 호텔안에만 있으니 해외 간 느낌이 들고 시설이 좋아서 편안')
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 예상 평점 4점 -> 부정 리뷰입니다.

# %%
review_predict('사이트와 다르게 조식은 제공 되지 않습니다. 해당 사항을 사전에 고지해주지 않습니다.')
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 예상 평점 1점 -> 매우 부정 리뷰입니다.

# %%
review_predict('청소가 아쉽습니다. 객실 및 침구 청소는 하시는데 화장실 및 욕조 청소는 안 되어있더라구요.')
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 예상 평점 0점 -> 매우 부정 리뷰입니다.

# %%
review_predict('직원들의 서비스, 주방장님의 정갈한 음식. 분위기도 조용하고.퀄러티는 초특급 5급인데요.')
# Out:
# 1/1 [==============================] - 0s 35ms/step
# 예상 평점 2점 -> 부정 리뷰입니다.

# %%
review_predict('아주 깨끗하고 청결하며 주인장이 너무 너무 친절함')
# Out:
# 1/1 [==============================] - 0s 225ms/step
# 예상 평점 9점 -> 매우 긍정 리뷰입니다.

# %% [markdown]
# ### 6. Wordclaud

# %%
tag_data.drop_duplicates(subset=['review'],inplace=True)
tag_review = [review for review in tag_data['review'] if type(review) is str]
counts = Counter(tag_review)
tags=counts.most_common(20) 
tags
# Out:
# [('시설도 깨끗하고 객실 뷰도 좋았어요!!! 수영장도 시설이 너무 좋았어요. 주차시설이 너무 좋았어요. 또 오고 싶네요. 애들 방학을 맞이하여 왔는데 담에 또 오고 싶네요...',
#   1),
#  ('돌담집을 제외한 다른 모든 면에서 만족스러운 호텔이었음(돌담집에서 고객을 응대하는 방법은 일반 여관이하의 수준이었음)', 1),
#  ('아침식사와 직원분들은 친절하셨습니다.', 1),
#  ('침대  윗쪽과 침대 옆 조명 윗쪽에 먼지가 많이 쌓여있었고 침대 옆쪽 콘센트가 고장 나서 휴대폰 충전을 하지 못했습니다. 그리고 저희 방쪽이 라운지때문인지 무엇 때문인지는 모르겠지만  밤에 쿵쿵 거리는 소리가 너무 심했습니다. 그리고 나이트 가운 끈쪽이 오염이 되어 있었습니다. 결론적으로 제가 예약 할때 청결 부분에 신경 많이 쓴다고 요청까지 하였는데 ...',
#   1),
#  ('어른5명 아이2명 방문했어요방도 세칸이고 방마다 침대가 있네요청소상태도 깨끗하고 넓어서 아이들과 지내기에 좋았어요', 1),
#  ('방키를 하나 밖에 받지 못해서 불편했습니다.\r\nSUV를 주차하기에 호텔 주차장 이용에 제한이 있어서 불편했습니다.\r\n주변 공용주차장을 이용했어요. \r\n발매트가 따로 있었으면 좋을 것 같습니다.',
#   1),
#  ('위치가 매일올레시장과 이중섭 거리, 해변과 가까워 걸어다니기에 안성맞춤이었습니다.\r\n5박 6일 동안 매일 방정리를 해 주시고, 3일째 침대보도 갈아 주셔서 보송보송하게 잘 지냈습니다.\r\n청소하시는 분들 수고 많으셨습니다.',
#   1),
#  ('뷰가 조금 아쉬웠습지요. 바다가 어설프게 보여서 감질맛이 났습니다.', 1),
#  ('월드컵경기장 근처  위치 좋구요, 수영장 이용 할 수 있어서 좋았습니다.', 1),
#  ('(구?)시가지의 중심에 위치하여 주변이 쾌적하지는 않지만 별로 불편하지도 않았슴', 1),
#  ('(프리미어)방이 매우 넓어서 쾌적하였슴.  청소 상태 매우 좋았슴.  주차 공간도 비교적 여유 있었슴.\r\n배를 타는 제주 여객선터미널이 가까워서 편리하였슴',
#   1),
#  ('10개월 아기와 함께하는 첫 여행이라 많은 걱정을하고갓지만,깔끔한 시설과 친절한 직원분들덕에 너무 편안한여행이였습니다.넓고 많은시설이 있어 다 둘러보고 이용하지못하고 와서 너무 아쉽습니다.',
#   1),
#  ('가격대비 룸 크기도 크고 위치도 좋았습니다. \n한라산 뷰도 좋습니다.', 1),
#  ('랜딩관 숙소 크기가 작아서 그런지 협탁과 의자가 없는 것이 조금 불편했습니다.그리고 마주보는 숙소 내 안이 너무 훤희 보여서 민망합니다. 외부에서 숙소 안이 보이지 않도록 선팅이 필요할 것 같습니다.',
#   1),
#  ('방배정받아 올라가니 이미 다른 사람들이 있었음.\n서로조심하는 시기에 다른 사람들이 잠시나마 있었던 방에서 묵기엔 좀 찝찝하였으나 호텔측 대처가 많이 부족함.',
#   1),
#  ('버스정류장 코앞', 1),
#  ('신회월드는 숙소도 좋지만 식당가가 훌륭합니다. 한식당 선은 매우 훌륭한데. 육전 강추입니다. 직원들의 서비스, 주방장님의 정갈한 음식. 분위기도 조용하고. 퀄러티는 초특급 5급인데. 가격은 초특급의 절반입니다. 호텔에 묵으시면 할인도 됩니다.',
#   1),
#  ('오래전부터 이용했는데 이제 시설이 낙후된거 같아요. 공조기 소리도 심하고', 1),
#  ('위아래 층에서 담배를 피는데 냄새가 바로 올라와요', 1),
#  ('이 리뷰는 이 호텔에 대한 나의 진실된 의견입니다. 나는 이 시설과 개인적 혹은 업무적인 관련이 없으며, 리뷰를 작성하는 조건으로 해당 시설로부터 금전적 또는 물질적인 대가를 제공받지 않았습니다',
#   1)]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
from wordcloud import WordCloud

wc = WordCloud('c:/Windows/Fonts/malgun.ttf',background_color='white').generate(' '.join(tag_review))

plt.figure(figsize=(10, 5))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
